# %% [markdown]
# <a href="https://colab.research.google.com/github/Rudrabhatt007/Data_Science/blob/main/important_series_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Some Important Series Methods**

# %%
#astype
#between
#clip
#drop_duplicates
#isnull
#dropna
#fillna
#isin
#apply
#copy

# %%
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv('/content/bollywood.csv')
movies
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
vk=pd.read_csv('/content/kohli_ipl.csv')
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
sub=pd.read_csv('/content/subs.csv')
sub
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
#astype
import sys
sys.getsizeof(vk)
# Out:
# 3584

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 1004

# %%
#between
vk[vk.between(51,99)].size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-30dccfb4a08f> in <cell line: 2>()
#       1 #between
# ----> 2 vk[vk.between(51,99)].size
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'between'

# %%
#clip
vk.clip(51,99)
# Out:
#      match_no  runs
# 0          51    51
# 1          51    51
# 2          51    51
# 3          51    51
# 4          51    51
# ..        ...   ...
# 210        99    51
# 211        99    51
# 212        99    73
# 213        99    51
# 214        99    51
#
# [215 rows x 2 columns]

# %%
#drop_duplicates
vk.drop_duplicates()
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
vk.duplicated().sum()
# Out:
# 0

# %%
temp=pd.Series([1,2,3,np.nan,5,7,8,89,np.nan,np.nan])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     7.0
# 6     8.0
# 7    89.0
# 8     NaN
# 9     NaN
# dtype: float64

# %%
#isnull
temp.isnull().sum()
# Out:
# 3

# %%
#dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     7.0
# 6     8.0
# 7    89.0
# dtype: float64

# %%
temp=pd.Series([1,2,3,np.nan,5,7,8,89,np.nan,np.nan])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     7.0
# 6     8.0
# 7    89.0
# 8     NaN
# 9     NaN
# dtype: float64

# %%
#fillna
temp.fillna(0)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     0.0
# 4     5.0
# 5     7.0
# 6     8.0
# 7    89.0
# 8     0.0
# 9     0.0
# dtype: float64

# %%
#isin
vk[(vk == 49)|(vk==99)]
# Out:
#      match_no  runs
# 0         NaN   NaN
# 1         NaN   NaN
# 2         NaN   NaN
# 3         NaN   NaN
# 4         NaN   NaN
# ..        ...   ...
# 210       NaN   NaN
# 211       NaN   NaN
# 212       NaN   NaN
# 213       NaN   NaN
# 214       NaN   NaN
#
# [215 rows x 2 columns]

# %%
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
vk[vk.isin([49,99])]
# Out:
#      match_no  runs
# 0         NaN   NaN
# 1         NaN   NaN
# 2         NaN   NaN
# 3         NaN   NaN
# 4         NaN   NaN
# ..        ...   ...
# 210       NaN   NaN
# 211       NaN   NaN
# 212       NaN   NaN
# 213       NaN   NaN
# 214       NaN   NaN
#
# [215 rows x 2 columns]

# %%
#apply
movies
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
movies.apply(lambda x: x.str.split().str[0].str.upper(), axis=1)
# Out:
#           movie     lead
# 0          URI:    VICKY
# 1     BATTALION    VICKY
# 2           THE   ANUPAM
# 3           WHY   EMRAAN
# 4       EVENING     MONA
# ...         ...      ...
# 1495        HUM     SHAH
# 1496    AANKHEN  AMITABH
# 1497   SAATHIYA    VIVEK
# 1498    COMPANY     AJAY
# 1499      AWARA   AKSHAY
#
# [1500 rows x 2 columns]

# %%
sub
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
sub['Subscribers gained'].apply(lambda x:'good day' if x > sub['Subscribers gained'].mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
#copy
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
new=vk.head()

# %%
new
# Out:
#    match_no  runs  1
# 0         1     1  5
# 1         2    23  5
# 2         3    13  5
# 3         4    12  5
# 4         5     1  5

# %%
new[1]=5
# Out:
# <ipython-input-56-52548b04fd7e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[1]=5
